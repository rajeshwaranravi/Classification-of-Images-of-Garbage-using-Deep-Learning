# %%
import random, os, glob
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator,array_to_img, img_to_array, load_img 
import numpy as np

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Initialising the ImageDataGenerator class. 
# We will pass in the augmentation parameters in the constructor. 
datagen = ImageDataGenerator(rescale=1. / 255,
                                   shear_range=40,fill_mode = 'constant', cval = 0)

# Loading a sample image  
img = load_img('/content/drive/MyDrive/Dataset/Dataset_Original/paper/paper509.jpg')  
# Converting the input sample image to an array 
x = img_to_array(img) 

# Reshaping the input image 
print(x.shape)
x = x.reshape((1, ) + x.shape)
print(x.shape)


x2 = datagen.flow(x, batch_size=1)
batch = x2.next()
image = batch[0]

plt.figure(figsize=(100,100))
plt.imshow(image)
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Loading a sample image  
img = load_img('/content/drive/MyDrive/Dataset/Dataset_Original/paper/paper509.jpg')  
# Converting the input sample image to an array 
x = img_to_array(img) 
# Reshaping the input image 
print(x.shape)
x = x.reshape((1, ) + x.shape)
print(x.shape)
# Out:
# (3024, 4032, 3)
# (1, 3024, 4032, 3)

# %%
datagen = ImageDataGenerator(rescale=1. / 255,zoom_range=0.7,fill_mode='constant', cval = 0)
# Loading a sample image  
img = load_img('/content/drive/MyDrive/Dataset/Dataset_Original/paper/paper509.jpg')  
# Converting the input sample image to an array 
x = img_to_array(img) 
# Reshaping the input image 
print(x.shape)
x = x.reshape((1, ) + x.shape)
print(x.shape)

x2 = datagen.flow(x, batch_size=1)
batch = x2.next()
image = batch[0]

plt.figure(figsize=(100,100))
plt.imshow(image)
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
datagen = ImageDataGenerator(rescale=1. / 255,rotation_range=40,fill_mode='constant',cval = 0)
# Loading a sample image  
img = load_img('/content/drive/MyDrive/Dataset/Dataset_Original/paper/paper509.jpg')  
# Converting the input sample image to an array 
x = img_to_array(img) 
# Reshaping the input image 
print(x.shape)
x = x.reshape((1, ) + x.shape)
print(x.shape)

x2 = datagen.flow(x, batch_size=1)
batch = x2.next()
image = batch[0]

plt.figure(figsize=(100,100))
plt.imshow(image)
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
datagen = ImageDataGenerator(rescale=1. / 255,width_shift_range=0.2,fill_mode='constant',cval = 0)
# Loading a sample image  
img = load_img('/content/drive/MyDrive/Dataset/Dataset_Original/paper/paper509.jpg')  
# Converting the input sample image to an array 
x = img_to_array(img) 
# Reshaping the input image 
print(x.shape)
x = x.reshape((1, ) + x.shape)
print(x.shape)

x2 = datagen.flow(x, batch_size=1)
batch = x2.next()
image = batch[0]

plt.figure(figsize=(100,100))
plt.imshow(image)
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
datagen = ImageDataGenerator(rescale=1. / 255,height_shift_range=0.2,fill_mode='constant',cval = 0)
# Loading a sample image  
img = load_img('/content/drive/MyDrive/Dataset/Dataset_Original/paper/paper509.jpg')  
# Converting the input sample image to an array 
x = img_to_array(img) 
# Reshaping the input image 
print(x.shape)
x = x.reshape((1, ) + x.shape)
print(x.shape)

x2 = datagen.flow(x, batch_size=1)
batch = x2.next()
image = batch[0]

plt.figure(figsize=(100,100))
plt.imshow(image)
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
datagen = ImageDataGenerator(rescale=1. / 255,horizontal_flip=True)
# Loading a sample image  
img = load_img('/content/drive/MyDrive/Dataset/Dataset_Original/paper/paper509.jpg')  
# Converting the input sample image to an array 
x = img_to_array(img) 
# Reshaping the input image 
print(x.shape)
x = x.reshape((1, ) + x.shape)
print(x.shape)

x2 = datagen.flow(x, batch_size=1)
batch = x2.next()
image = batch[0]

plt.figure(figsize=(100,100))
plt.imshow(image)
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Generating and saving 5 augmented samples  
# using the above defined parameters.  
i = 0
for batch in datagen.flow(x, batch_size = 1, 
                          save_to_dir ='/content/drive/MyDrive/PreProcessing',  
                          save_prefix = 'image' + str(i), save_format ='jpg'): 
    i = i + 1
    if i > 5: 
        break

# %%
plt.figure(figsize=(100,100))

x = datagen.flow(x, batch_size=1)

for i in range(6):
  plt.figure(figsize=(100,100))
  plt.subplot(6,6,i+1)
  batch = x.next()
  print(i)
  image = batch[0]
  plt.imshow(image)
  plt.show()
